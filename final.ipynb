# %%
from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_iris 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier 
from matplotlib import pyplot as plt
from sklearn.model_selection import cross_val_score

iris = load_iris() 
x, y = load_iris(return_X_y=True) 

x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=1) 

decision_tree = DecisionTreeClassifier(random_state=1).fit(x_train, y_train) 

#Create tree graph
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(decision_tree, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

scores = cross_val_score(decision_tree, x_test, y_test, cv=10) 
print(scores)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# [1.         1.         1.         1.         1.         1.
#  1.         0.66666667 0.66666667 0.66666667]

# %%
from sklearn import svm 
from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score

iris = load_iris() 
x, y = load_iris(return_X_y=True) 
x_train, x_test, y_train, y_test = train_test_split(x, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=1)
 
model=svm.SVC(kernel='linear',random_state=1).fit(x_train, y_train)


scores = cross_val_score(model, x_test, y_test, cv=10) 
print(scores)
# Out:
# [1.         1.         1.         1.         1.         1.
#  1.         1.         1.         0.66666667]
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
